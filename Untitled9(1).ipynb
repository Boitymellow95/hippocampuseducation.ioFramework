# %% [markdown]
# hippocampuseducation  learning pattens and prediction models
# import libraries

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# %%
df = pd.read_csv('hippo.csv')

# %%
df.head()
# Out:
#   student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2  \
# 0  2425844;13:23:00;20:23;16:29:00;05/12/2021;3;1...
# 1  2466429;  17:43:00;19:11;10:21:00;05/12/2021;1...
# 2  2387231;  20:07:07;01:43;12:29:00;04/12/2021;1...
# 3  2489211;  20:07:07;16:26;14:12:00;02/12/2021;0...
# 4  2455304;  17:39:07;19:00;12:45:00;05/12/2021;6...
#
#    2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.tail()
# Out:
#    student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2  \
# 9   1603806;  20:29:08;21:04;;05/12/2021;2;1;no at...
# 10  2429308;  14:18:09;16:04;;05/12/2021;0;no atte...
# 11  2443532;  08:47:10; 19:41:00;;29/11/2021;3d9h2...
# 12  2483953;null;null;null;null;set2 only;null;nul...
# 13  2443377;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;...
#
#     2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3  \
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#     2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN

# %%
def DescriptiveStatistics(df):
    print("No of rwos and columns information:",df.shape)
    print("")
    print("---"*20)
    print("")
    print("Columns:")
    print("")
    print(df.columns.values)
    print("---"*20)
    print("")
    print(df.info())
    print("---"*20)
    print("")
    print(df.describe())

# %%
DescriptiveStatistics(df)
# Out:
# No of rwos and columns information: (14, 3)
#
# ------------------------------------------------------------
#
# Columns:
#
# ['student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2'
#  '2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3'
#  '2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation']
# ------------------------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                               --------------  -----
#  0   student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2                                                                                                       14 non-null     object
#  1   2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3                                                                                                                                                                                                                                                 0 non-null      float64
#  2   2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation  0 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 464.0+ bytes
# None
# ------------------------------------------------------------
#
#        2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN

# %%
def CheckMissingInfo(df):
    print(df.isnull().sum())
    print("---"*20)
    print("")
    df_na = (df.isnull().sum() / len(df)) * 100
    df_na = df_na.drop(df_na[df_na == 0].index).sort_values(ascending=False)[:30]
    missing_data = pd.DataFrame({'Missing Ratio' :df_na})
    print(missing_data)

# %%
CheckMissingInfo(df)
# Out:
# student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2                                                                                                          0
# 2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3                                                                                                                                                                                                                                                   14
# 2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation    14
# dtype: int64
# ------------------------------------------------------------
#
#                                                     Missing Ratio
# 2nd attempt;q2.2;q2.3;see explanation;view solu...          100.0
# 2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;v...          100.0

# %%
def GetColumnCount(df):
    int_columns = [col for col in df.columns if(df[col].dtype != "object")]
    print("No of integer type columns:",len(int_columns))
    print(int_columns)
    print("")
    obj_columns = [col for col in df.columns if(df[col].dtype == "object")]
    print("No of object type columns:",len(obj_columns))
    print(obj_columns)
    return int_columns,obj_columns

# %%
int_columns,obj_columns = GetColumnCount(df)
# Out:
# No of integer type columns: 2
# ['2nd attempt;q2.2;q2.3;see explanation;view solution;textbook;lecture;video;q3;q3.1;q3.2;duaration q3', '2nd attempt;q3.3;q3.1.1;q 3.1.2;q3.1.3;q3.1.1;view_solution;Video;textbook;lecture;see explanation;q4;q4.1;view solution;q4.1.1;video;q4.1.2;q4.2;q4.1.3;q4.3;duaration for 2nd attem q4;lecture;textbook;see explanation;q5;q 5.1;q 5.1.1;q5.1.2;q5.1.3;q5.2;q5.3;duaration on q5 2nd attempt;view solution;Video;textbook;lecture;see explanation']
#
# No of object type columns: 1
# ['student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2']

# %% [markdown]
# VISUALS OF THE DATASET bold text

# %%
def GetCountPlots(df,obj_columns):
    for col in obj_columns:
        if(len(df[col].value_counts()) < 5):
            plt.figure(figsize=(5,5))
        else:
            plt.figure(figsize=(12,6))
        print(sns.countplot(x=col, data=df, palette="muted"))
        plt.show()

# %%
sns.set(); np.random.seed(0)
x = np.random.randn(100)

sns.distplot(x)
# Out:
# C:\Users\boitu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
pip install -U statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\boitu\anaconda3\lib\site-packages (0.13.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy>=1.17 in c:\users\boitu\anaconda3\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\boitu\anaconda3\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\boitu\anaconda3\lib\site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\boitu\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\boitu\anaconda3\lib\site-packages (from statsmodels) (21.3)
#
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\boitu\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\boitu\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\boitu\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in c:\users\boitu\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
sns.distplot(x, bins=50, kde=False)
plt.show()
# Out:
# C:\Users\boitu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#bargraph of the learning events 

GetCountPlots(df,obj_columns)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
def GetCardinality(df,obj_columns):
    for col in obj_columns:
        print("{0} :: {1}".format(col,len(df[col].value_counts())))
        
        print(df[col].value_counts())
        print("")

# %%
GetCardinality(df,obj_columns)
# Out:
# student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2 :: 14
# 2425844;13:23:00;20:23;16:29:00;05/12/2021;3;1;no attempt;no attempt;no attempt;0;no attemptno attempt;0;no attempt;no attempt;no attempt;4;no attempt;5;4;no attempt;no attempt;no attempt;2;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;10;no attempt;no attempt;2;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;1;no attempt;;;;;;;no attempt;no attempt;no attempt;no ;0;3;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;pass;no attempt;no attempt;no attempt;no attempt;no attempt                                                                                                                    1
# 2466429;  17:43:00;19:11;10:21:00;05/12/2021;12;NO ATTEMP ;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;29;13;no attempt;no attempt;no attempt;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;15;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;13;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;5;no attempt;4;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;;no attempt;no attempt;no attempt;no attempt;no attempt            1
# 2387231;  20:07:07;01:43;12:29:00;04/12/2021;18;2;0;3;2;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;0;no attempt;16;13;4;0;0;1;33;0;no attempt;no attempt;no attempt;no attempt;no attempt;23;32;15;22;no attempt;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;4;11;1;3;5;8;5;4;5;0;no attempt;no attempt;no attempt;12;2;2;2;no attempt;11;7;5;1;no attempt;no attempt;no attempt;0                                                                                                                                                                                                                                                                          1
# 2489211;  20:07:07;16:26;14:12:00;02/12/2021;02d20h02m;10;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;6;no attempt;6;1;7;15;1;2;3;3;no attempt;0;1;no attempt;1;9;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;;;;;;;;;;;;;;;;;;; ;;;                                                                                                                                                                                                                                                                                                1
# 2455304;  17:39:07;19:00;12:45:00;05/12/2021;6;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;4;4;2;1;no attempt;2;2;4;;no attempt;no attempt;no attempt;no attempt;10;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;0;4;;1;no attempt;no attempt;17;no attempt;no attempt;3;no attempt;no attempt;no attempt;7;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt                                                                                        1
# 1849534;  16:32:07;14:33;;09/12/2021;2;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;2;no attempt;45;5;1;no attempt;no attempt;1;1;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;2;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;;;;;;;;;;;;;;;                                                                                                                                                                                      1
# 2483688;  15:30:07;15:57;;05/12/2021;0;1;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;0;no attempt;9;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;4;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;5;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;3;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt      1
# 2328014;  20:07:07;20:26;;05/12/2021;set2 only;null;null;null;null;null;null;null;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# 2431095;  11:40:07;15:46;;02/12/2021;18;6;no attempt;1;2;1;no attempt;no attempt;no attempt;0;0;fail;no attempt;40;21;no attempt;no attempt;no attempt;5;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;12;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;4;44;0;3;no attempt;13;1;4;24;0;no attempt;no attempt;no attempt;5;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;16;no attempt;no attempt;no attempt;no attempt;no attempt                                                                                                                                           1
# 1603806;  20:29:08;21:04;;05/12/2021;2;1;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;1;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;13;1;;;;;;;;;;;                                                                                                 1
# 2429308;  14:18:09;16:04;;05/12/2021;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;0;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;12;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;1;13;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;3;no attempt;no attempt;no attempt;6;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt    1
# 2443532;  08:47:10; 19:41:00;;29/11/2021;3d9h24m;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;35;5;no attempt;no attempt;no attempt;9;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;17;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;12;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;no attempt;14;no attempt;no attempt;no attempt;no attempt;no attempt;;;;;;;                                                              1
# 2483953;null;null;null;null;set2 only;null;null;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# 2443377;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Name: student_id;start_assesment ;end_assesment;video duaration for set1;date;question_1;question_1.1;view_solution;q_1.1.1;q1.2;q1.1.2;watch video ;q1.1.3;text book;1.3;Explanation;duaration_1;lecture;q2;q2.1;q2.1.1;q 2.1.2;q2.1.3;duaration q2, dtype: int64

# %%
def GetCountPlots_with_hue(df,obj_columns,col_hue):
    for col in obj_columns:
        if(len(df[col].value_counts()) < 5):
            plt.figure(figsize=(5,5))
        else:
            plt.figure(figsize=(12,6))
        #print(sns.countplot(x=col, data=df, palette="muted"))
        sns.countplot(x=col,data = df, hue=col_hue,palette='bright')
        plt.show()

# %%
GetCountPlots_with_hue(df,obj_columns,'Class')

# %%
def GetBoxPlots(df,x_col):
    for col in int_columns:
        plt.figure(figsize=(5,5))
        boxplot1 = sns.boxplot(x=x_col, y=col, data=df)
        boxplot1 = sns.swarmplot(x=x_col, y=col, data=df, color=".15")
        plt.show()

# %%
df['Failed'] = np.where(df['Class']=='L',1,0)

# %%
df['AbsBoolean'] = df['views video']
df['AbsBoolean'] = np.where(df['AbsBoolean'] == 'Under-7',0,1)
df['AbsBoolean'].groupby(df['Topic']).mean()

# %%
df.head()

# %%
df.info()

# %%
def NumaricVariablesDistributions(df):
    int_columns=df.columns[df.dtypes==int]
    plt.figure(figsize=(10,7))
    for i, column in enumerate(int_columns):
        plt.subplot(3,2, i+1)
        sns.distplot(df[column], label=column, bins=10, fit=norm)
        plt.ylabel('Density');

# %%
NumaricVariablesDistributions(df)  

#Features doesn't have gaussian (normal) distribution.
#As ML algorithms deal better with values, which are normally distributed
